# %%
import os

# %%
from configparser import ConfigParser

# %%
config=ConfigParser()

# %%
os.getcwd()
# Out:
# 'd:\\Data Science\\LangChainLangGraph_class\\LangGraphProjects\\src\\langgrapgagenticai\\ui'

# %%
config_file="uiconfigfile.ini"
config.read(config_file)
# Out:
# ['uiconfigfile.ini']

# %%
config["DEFAULT"].get("LLM_OPTIONS").split(", ")
# Out:
# ['Groq']

# %%
def get_usecase_options():
        return config["DEFAULT"].get("LLM_OPTIONS").split(", ")

# %%
get_usecase_options()
# Out:
# ['Groq']
